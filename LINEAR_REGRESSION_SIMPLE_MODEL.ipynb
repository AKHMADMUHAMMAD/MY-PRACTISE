# %% [markdown]
# <a href="https://colab.research.google.com/github/AKHMADMUHAMMAD/MY-PRACTISE/blob/main/LINEAR_REGRESSION_SIMPLE_MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 5-MODUL. Machine Learning.
#
# ### Amaliyot. Simple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/reklama_sales.csv')
df.head(20)
# Out:
#        TV  Radio  Newspaper  Sales
# 0   230.1   37.8       69.2   22.1
# 1    44.5   39.3       45.1   10.4
# 2    17.2   45.9       69.3   12.0
# 3   151.5   41.3       58.5   16.5
# 4   180.8   10.8       58.4   17.9
# 5     8.7   48.9       75.0    7.2
# 6    57.5   32.8       23.5   11.8
# 7   120.2   19.6       11.6   13.2
# 8     8.6    2.1        1.0    4.8
# 9   199.8    2.6       21.2   15.6
# 10   66.1    5.8       24.2   12.6
# 11  214.7   24.0        4.0   17.4
# 12   23.8   35.1       65.9    9.2
# 13   97.5    7.6        7.2   13.7
# 14  204.1   32.9       46.0   19.0
# 15  195.4   47.7       52.9   22.4
# 16   67.8   36.6      114.0   12.5
# 17  281.4   39.6       55.8   24.4
# 18   69.2   20.5       18.3   11.3
# 19  147.3   23.9       19.1   14.6

# %%
df.shape
# Out:
# (200, 4)

# %% [markdown]
# Yuqoridagi jadvalda MohirDev MChJ tomonidan turli OAV larda (`TV`, `Radio`, `Newspaper`) berilgan reklamalar soni va mos keluvchi savdolar (`Sales`) berilgan.
#
# Sizning vazifangiz:
# 1. Aynan qaysi turdagi OAVda reklama berish savdo o'sishiga ta'sir qiladi aniqlash
# 2. Topilgan bog'liqlik asosida Simple Linear Regression algorithmi yordamida bashorat modelini qurish.

# %% [markdown]
# Ushbu amaliyotda sizning vazifangiz berilgan dataset yordamida Simple Linear Regression model yaratish:
# - CRISP-DM metodologiyasiga amal qiling!
# - Simple linear regression qo'llash uchun 1 ta ustunni tanlab oling.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='Sales',y='TV')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='Sales',y='Radio')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='Sales',y='Newspaper')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=df, x='TV', y='Sales', line_kws={"color": "red"})
plt.show()

# %%
from sklearn.model_selection import train_test_split
train_set,test_set = train_test_split(df, test_size = 0.05,random_state=42)

x_train = train_set['TV']
y_train = train_set['Sales']

x_test = test_set['TV']
y_test = test_set['Sales']

# %%
from sklearn import linear_model
LNR_model = linear_model.LinearRegression()


# numpy arrayga o'tkazib olamiz
x_train = np.asanyarray(train_set[['TV']])
y_train = np.asanyarray(train_set[['Sales']])

# Machine Learning qilamiz

LNR_model.fit(x_train,y_train)

# theta1 va theta0 koeefitsentlarni ajeatib olamiz

theta1 = LNR_model.coef_[0][0]
theta0 = LNR_model.intercept_[0]

print(f'{theta1=}')
print(f'{theta0 =}')
# Out:
# theta1=np.float64(0.05513998038738684)
# theta0 =np.float64(6.975831973401382)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='TV', y='Sales')
plt.plot(x_train, theta1*x_train + theta0, '-r')
plt.xlabel("Size")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
x_test = np.asanyarray(test_set[['TV']])
y_test =np.asanyarray(test_set[['Sales']])

# %%
y_predict = LNR_model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
MAE = mean_absolute_error(y_test,y_predict)
RMSE = np.sqrt(mean_squared_error(y_test,y_predict))

print(f'MAE={MAE:.2f}')
print(f'RMSE={RMSE:.2f}')
# Out:
# MAE=2.26
# RMSE=2.82
